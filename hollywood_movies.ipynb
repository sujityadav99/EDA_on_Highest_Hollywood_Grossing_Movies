# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Highest Holywood Grossing Movies.csv')

# %%
df
# Out:
#      Unnamed: 0                                              Title  \
# 0             0  Star Wars: Episode VII - The Force Awakens (2015)
# 1             1                           Avengers: Endgame (2019)
# 2             2                                      Avatar (2009)
# 3             3                               Black Panther (2018)
# 4             4                      Avengers: Infinity War (2018)
# ..          ...                                                ...
# 913         913                                The Notebook (2004)
# 914         914                   Jimmy Neutron: Boy Genius (2001)
# 915         915                               Eat Pray Love (2010)
# 916         916                 The Texas Chainsaw Massacre (2003)
# 917         917                                   Zookeeper (2011)
#
#                                             Movie Info  \
# 0    As a new threat to the galaxy rises, Rey, a de...
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Title', 'Movie Info', 'Distributor', 'Release Date',
#        'Domestic Sales (in $)', 'International Sales (in $)',
#        'World Sales (in $)', 'Genre', 'Movie Runtime', 'License'],
#       dtype='object')

# %%
df.shape
# Out:
# (918, 11)

# %%
df.isna().sum()
# Out:
# Unnamed: 0                      0
# Title                           0
# Movie Info                      0
# Distributor                     0
# Release Date                  118
# Domestic Sales (in $)           0
# International Sales (in $)      0
# World Sales (in $)              0
# Genre                           0
# Movie Runtime                   0
# License                       174
# dtype: int64

# %%
df.drop(['Release Date','License'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (918, 9)

# %%
df.isna().sum()
# Out:
# Unnamed: 0                    0
# Title                         0
# Movie Info                    0
# Distributor                   0
# Domestic Sales (in $)         0
# International Sales (in $)    0
# World Sales (in $)            0
# Genre                         0
# Movie Runtime                 0
# dtype: int64

# %%
df.Distributor.unique()
# Out:
# array(['Walt Disney Studios Motion Pictures', 'Twentieth Century Fox',
#        'Sony Pictures Entertainment (SPE)', 'Paramount Pictures',
#        'Universal Pictures', 'Warner Bros.', 'DreamWorks Distribution',
#        'Lionsgate', 'DreamWorks', 'New Line Cinema', 'Newmarket Films',
#        'Summit Entertainment', 'Columbia Pictures', 'IFC Films',
#        'TriStar Pictures', 'Orion Pictures', 'Metro-Goldwyn-Mayer (MGM)',
#        'Miramax', 'The Weinstein Company', 'Fox Searchlight Pictures',
#        'Revolution Studios', 'Artisan Entertainment',
#        'Sony Pictures Classics', 'United Artists', 'Screen Gems',
#        'USA Films', '20th Century Studios', 'STX Entertainment',
#        'Dimension Films', 'United Artists Releasing', 'FilmDistrict',
#        'Focus Features', 'Relativity Media', 'Roadside Attractions'],
#       dtype=object)

# %%
df.Distributor.nunique()

# %%
# largest dristributor
df.Distributor.value_counts()
# Out:
# Warner Bros.                           158
# Walt Disney Studios Motion Pictures    155
# Universal Pictures                     119
# Twentieth Century Fox                  117
# Sony Pictures Entertainment (SPE)      101
# Paramount Pictures                      99
# DreamWorks                              21
# New Line Cinema                         21
# Lionsgate                               19
# DreamWorks Distribution                 17
# Metro-Goldwyn-Mayer (MGM)               12
# TriStar Pictures                         9
# Miramax                                  9
# Revolution Studios                       8
# Columbia Pictures                        7
# Dimension Films                          7
# The Weinstein Company                    6
# Summit Entertainment                     5
# Fox Searchlight Pictures                 4
# STX Entertainment                        3
# Orion Pictures                           3
# Screen Gems                              3
# ...

# %%
df.Distributor.value_counts().head(1)
# Out:
# Warner Bros.    158
# Name: Distributor, dtype: int64

# %%
df.Distributor.value_counts().head(10).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.Distributor.value_counts().head(10).plot(kind='bar',rot=90,xlabel='distributor')
# Out:
# <AxesSubplot:xlabel='distributor'>

# %%
a = df.sort_values('Movie Runtime').tail(1)

# %%
a
# Out:
#      Unnamed: 0                  Title  \
# 433         433  The Green Mile (1999)
#
#                                             Movie Info   Distributor  \
# 433  The lives of guards on Death Row are affected ...  Warner Bros.
#
#      Domestic Sales (in $)  International Sales (in $)  World Sales (in $)  \
# 433              136801374                   150000000           286801374
#
#                                         Genre Movie Runtime
# 433  ['Crime', 'Drama', 'Fantasy', 'Mystery']    3 hr 9 min

# %%
a[['Title','Movie Runtime']]
# Out:
#                      Title Movie Runtime
# 433  The Green Mile (1999)    3 hr 9 min

# %%
df[df['Movie Runtime'] == df['Movie Runtime'].max()]
# Out:
#      Unnamed: 0                  Title  \
# 433         433  The Green Mile (1999)
#
#                                             Movie Info   Distributor  \
# 433  The lives of guards on Death Row are affected ...  Warner Bros.
#
#      Domestic Sales (in $)  International Sales (in $)  World Sales (in $)  \
# 433              136801374                   150000000           286801374
#
#                                         Genre Movie Runtime
# 433  ['Crime', 'Drama', 'Fantasy', 'Mystery']    3 hr 9 min

# %%
# max collection
df.sort_values('Domestic Sales (in $)').tail(1)
# Out:
#    Unnamed: 0                                              Title  \
# 0           0  Star Wars: Episode VII - The Force Awakens (2015)
#
#                                           Movie Info  \
# 0  As a new threat to the galaxy rises, Rey, a de...
#
#                            Distributor  Domestic Sales (in $)  \
# 0  Walt Disney Studios Motion Pictures              936662225
#
#    International Sales (in $)  World Sales (in $)  \
# 0                  1132859475          2069521700
#
#                                Genre Movie Runtime
# 0  ['Action', 'Adventure', 'Sci-Fi']   2 hr 18 min

# %%
df.sort_values('International Sales (in $)').tail(1)
# Out:
#    Unnamed: 0          Title  \
# 2           2  Avatar (2009)
#
#                                           Movie Info            Distributor  \
# 2  A paraplegic Marine dispatched to the moon Pan...  Twentieth Century Fox
#
#    Domestic Sales (in $)  International Sales (in $)  World Sales (in $)  \
# 2              760507625                  2086738578          2847246203
#
#                                           Genre Movie Runtime
# 2  ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']   2 hr 42 min

# %%
df.nlargest(1,'Domestic Sales (in $)')
# Out:
#    Unnamed: 0                                              Title  \
# 0           0  Star Wars: Episode VII - The Force Awakens (2015)
#
#                                           Movie Info  \
# 0  As a new threat to the galaxy rises, Rey, a de...
#
#                            Distributor  Domestic Sales (in $)  \
# 0  Walt Disney Studios Motion Pictures              936662225
#
#    International Sales (in $)  World Sales (in $)  \
# 0                  1132859475          2069521700
#
#                                Genre Movie Runtime
# 0  ['Action', 'Adventure', 'Sci-Fi']   2 hr 18 min

# %%
df.nsmallest(1,'Domestic Sales (in $)')
# Out:
#      Unnamed: 0             Title  \
# 917         917  Zookeeper (2011)
#
#                                             Movie Info  \
# 917  A group of zoo animals decide to break their c...
#
#                            Distributor  Domestic Sales (in $)  \
# 917  Sony Pictures Entertainment (SPE)               80360843
#
#      International Sales (in $)  World Sales (in $)  \
# 917                    89491916           169852759
#
#                                           Genre Movie Runtime
# 917  ['Comedy', 'Family', 'Fantasy', 'Romance']   1 hr 42 min

# %%
df
# Out:
#      Unnamed: 0                                              Title  \
# 0             0  Star Wars: Episode VII - The Force Awakens (2015)
# 1             1                           Avengers: Endgame (2019)
# 2             2                                      Avatar (2009)
# 3             3                               Black Panther (2018)
# 4             4                      Avengers: Infinity War (2018)
# ..          ...                                                ...
# 913         913                                The Notebook (2004)
# 914         914                   Jimmy Neutron: Boy Genius (2001)
# 915         915                               Eat Pray Love (2010)
# 916         916                 The Texas Chainsaw Massacre (2003)
# 917         917                                   Zookeeper (2011)
#
#                                             Movie Info  \
# 0    As a new threat to the galaxy rises, Rey, a de...
# ...

# %%
for i in (df.Title.str.split()):
    print(i[-1])
# Out:
# (2015)
# (2019)
# (2009)
# (2018)
# (2018)
# (2021)
# (1997)
# (2015)
# (2012)
# (2017)
# (2018)
# (2019)
# (2008)
# (2016)
# (2019)
# (2017)
# (2016)
# (2019)
# (1999)
# (1977)
# (2015)
# (2012)
# (2004)
# (1982)
# (2019)
# (2019)
# (2013)
# (2006)
# (1994)
# (2018)
# (2010)
# (2017)
# (2013)
# (2016)
# (2012)
# (2002)
# (2017)
# (1993)
# (2009)
# (2013)
# (2019)
# (2017)
# (2011)
# (2003)
# (2005)
# (2003)
# (2004)
# (2004)
# (2016)
# (2013)
# (2016)
# (2016)
# (2015)
# (2019)
# (2015)
# (2011)
# (2014)
# (2002)
# (2016)
# (2014)
# (2007)
# (2015)
# (2019)
# (2018)
# (2017)
# (2010)
# (2014)
# (1994)
# (2016)
# (2017)
# (2016)
# (2018)
# (2007)
# (2019)
# (2007)
# (2008)
# (2001)
# (2008)
# (2001)
# (2017)
# (2010)
# (2002)
# (2007)
# (1983)
# (1996)
# (2003)
# (2012)
# (2012)
# (2009)
# (2010)
# (2009)
# (2010)
# (1999)
# (2009)
# (1980)
# (2010)
# (2007)
# (2012)
# (2005)
# (2013)
# (2001)
# (2005)
# (1990)
# (2015)
# (2003)
# (2011)
# (2004)
# (2009)
# (2013)
# (2018)
# (2016)
# ...

# %%
l = []
for i in (df.Title.str.split()):
    l.append(i[-1])
#     print(i[-1],end='')
l.sort()
print(l)
# Out:
# ['(1937)', '(1953)', '(1955)', '(1970)', '(1972)', '(1973)', '(1975)', '(1977)', '(1977)', '(1978)', '(1978)', '(1979)', '(1979)', '(1979)', '(1980)', '(1980)', '(1981)', '(1981)', '(1982)', '(1982)', '(1983)', '(1983)', '(1984)', '(1984)', '(1985)', '(1985)', '(1986)', '(1986)', '(1986)', '(1987)', '(1988)', '(1988)', '(1988)', '(1988)', '(1989)', '(1989)', '(1989)', '(1989)', '(1990)', '(1990)', '(1990)', '(1990)', '(1990)', '(1990)', '(1990)', '(1990)', '(1990)', '(1990)', '(1990)', '(1991)', '(1991)', '(1991)', '(1991)', '(1991)', '(1991)', '(1991)', '(1991)', '(1991)', '(1992)', '(1992)', '(1992)', '(1992)', '(1992)', '(1992)', '(1992)', '(1992)', '(1992)', '(1992)', '(1992)', '(1992)', '(1992)', '(1992)', '(1992)', '(1993)', '(1993)', '(1993)', '(1993)', '(1993)', '(1993)', '(1993)', '(1993)', '(1993)', '(1993)', '(1994)', '(1994)', '(1994)', '(1994)', '(1994)', '(1994)', '(1994)', '(1994)', '(1994)', '(1994)', '(1994)', '(1994)', '(1994)', '(1994)', '(1995)', '(1995)', '(1995)
# ...

# %%
df.Title.value_counts()
# Out:
# Star Wars: Episode VII - The Force Awakens (2015)    1
# Glass (2019)                                         1
# Sing 2 (2021)                                        1
# Tropic Thunder (2008)                                1
# Godzilla: King of the Monsters (2019)                1
#                                                     ..
# Casino Royale (2006)                                 1
# Meet the Parents (2000)                              1
# Fifty Shades of Grey (2015)                          1
# 2012 (2009)                                          1
# Zookeeper (2011)                                     1
# Name: Title, Length: 918, dtype: int64

# %%
df
# Out:
#      Unnamed: 0                                              Title  \
# 0             0  Star Wars: Episode VII - The Force Awakens (2015)
# 1             1                           Avengers: Endgame (2019)
# 2             2                                      Avatar (2009)
# 3             3                               Black Panther (2018)
# 4             4                      Avengers: Infinity War (2018)
# ..          ...                                                ...
# 913         913                                The Notebook (2004)
# 914         914                   Jimmy Neutron: Boy Genius (2001)
# 915         915                               Eat Pray Love (2010)
# 916         916                 The Texas Chainsaw Massacre (2003)
# 917         917                                   Zookeeper (2011)
#
#                                             Movie Info  \
# 0    As a new threat to the galaxy rises, Rey, a de...
# ...

# %%
df.Genre
# Out:
# 0                      ['Action', 'Adventure', 'Sci-Fi']
# 1             ['Action', 'Adventure', 'Drama', 'Sci-Fi']
# 2           ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']
# 3                      ['Action', 'Adventure', 'Sci-Fi']
# 4                      ['Action', 'Adventure', 'Sci-Fi']
#                              ...
# 913                                 ['Drama', 'Romance']
# 914    ['Action', 'Adventure', 'Animation', 'Comedy',...
# 915                    ['Biography', 'Drama', 'Romance']
# 916                                  ['Crime', 'Horror']
# 917           ['Comedy', 'Family', 'Fantasy', 'Romance']
# Name: Genre, Length: 918, dtype: object

# %%
(df.Genre == "['Comedy']").sum()
# Out:
# 35

# %%
n = 0
for i in df.Genre:
    if 'Comedy' in i:
#         print(i)
        n = n + 1
print(n)
# Out:
# 399
